# %% [markdown]
# ## 실습 1. 여러 페이지의 기사 제목 수집하기
# 1,2,3… 등으로 구분된 페이지에 있는 기사들의 제목을 한번에 수집하고자 합니다.
#
# 실습을 진행하는 웹 사이트 주소입니다. https://sports.donga.com/ent?p=1&c=02

# %%
import requests
from bs4 import BeautifulSoup

def crawling(soup) :
    # soup 객체에서 추출해야 하는 정보를 찾고 반환하세요.
    ul = soup.find("ul", class_="list_news")
    result = []

    for span in ul.find_all("span", class_="tit"):
      result.append(span.get_text())

    return result
    


def main() :
    answer = []
    url = "https://sports.donga.com/ent"
    
    for i in range(0, 5):
        req = requests.get(url, params={'p':i*20+1})
        soup = BeautifulSoup(req.text, "html.parser")
        
        answer += crawling(soup)

    # crawling 함수의 결과를 출력합니다.
    print(answer)


if __name__ == "__main__" :
    main()
# Out:
# ['[TV체크] ‘식스센스’ 차태현 주도한 유재석 몰이, 꿀잼 그 자체', '첫방 D·1 ‘날아라 개천용’ 권상우 ‘단짠’ 활약 주목', '‘날아라 개천용’ 배성우, 김응수 향해 짠내 묻고 반격 더블로', '‘궁금한 이야기Y’ 독감 백신 사망 사태 조명…진실은?', '[종합] 환불원정대 야구장도 씹어먹었다→11월 방송 예정', '[포토] 환불원정대, 가요계 씹어먹더니…그라운드도 올킬', '[포토] 환불원정대, 어서와 야구장 공연은 처음이지?', '[포토] 환불원정대, 이쯤되면 코로나19도 박살낼 기세', '[포토] 환불원정대, 절대로 안 꿀리는 언니들', '[포토] 환불원정대, 치어리더들 기죽이는 퍼포먼스', '[포토] 환불원정대 저돌적 퍼포먼스 ‘지미유 보고 있나’', "[포토] 환불원정대, ‘DON'T TOUCH ME’", '[포토] 환불원정대 제시, 시구도 눈누나나~', '[포토] 환불원정대 제시, 시구 컴~온!', '[포토] 환불원정대 이효리 보고있나 (ft.배트우먼)', '[포토] 환불원정대 이효리, 배트 잡는 솜씨 예사롭지 않아', '[포토] 환불원정대 제시, 이효리 향한 美친 시구', '황제성, ‘더 먹고 가’ 출연확정…강호동과 예능 호흡 [공식]', '[TV북마크] ‘유퀴즈’ 최고 3.7%→역대 최고, 김재연·김용덕 대표 등 화…', '[DA:클립] ‘나는 살아있다’ 이시영→김민경, 피땀눈물 영상 공개', '잔나비, 11월 6일 새 앨범 ‘잔나비 소곡집 1’ 발매 확정 [공식]', '‘명량’→‘청춘기록’ 박보검 연기史, 특별하지 아니한가', '개그우먼 이수지, ‘서프라이즈’ 새 코너 MC 발탁', '[DAY컷] 혜리 10주년 “앞으로 더 잘할 것”…미모 포텐', '박성준, ‘런온’ 출연확정…임시완과 호흡 [공식]', '고현정, 매니쉬→고혹美 소화…역대급 미모 [화보]', '‘식스센스’ 차태현 게스트 출연…믿고 보는 예능감 대미 장식', '[DAY컷] ‘한다다’ 기도훈 SNS 해킹 피해 “조심하세요”', '엑소 찬열 전 여친 폭로…촬영 마친 ‘더 박스’ 후반 작업 중 ‘봉변’ [공식…', '‘스타트업’ 배수지·남주혁, 청량함 가득 미공개 스틸컷 공개', '원현준 프레인TPC와 전속계약, 오정세·김무열과
까지', '홍진영, 신곡 ‘안돼요’ 영상 공개…11월 2일 발매', '찬열·로제 합성 사진, 디스패치 “사칭 행위에 법적대응” [공식입장]', '신동엽X김원희, ‘우리 이혼했어요’ MC 확정…13년만에 재회 [공식]', '‘런온’ 임시완 첫 스틸컷…‘인생 프리패스’ 증명 비주얼', '[DA:재팬] 배우 이토 켄타로 뺑소니 혐의…피해자들 중경상', '‘라이브온’ 황민현·정다빈 첫 커플 스틸 공개…찰떡 비주얼 케미', '‘어서와’ 프랑스 출신 호만, LG전자 최첨단 사무실 공개 (ft.조식 로봇)', '‘어서와’ 새 MC 박지민 “MBC 구내식당 맛있어” 남다른 애사심', '관효동, 공주같이 우아하면서 사랑스러운 분위기 [포토화보]', '강호동X임지호 셰프, ‘더 먹고가’ 11월 8일 첫방 확정 [공식]', '‘산골 축구단’ 김재환 “음악보다 축구 더 좋아”', '호피폴라 하현상, 11월 10일 솔로 컴백', '에밀리 라타이코프스키, 임신 중에도 과감하게 드러내는 허리 라인 [포토화보]', '[종합] 엑소 찬열 전 여친 폭로글→SM 입장 無…애꿎은 로제 ‘날벼락’', '‘안다행’ 박명수 "나이 오십에 욕 제대로 먹었다" 분노', '‘구미호뎐’ 이동욱, 극 초반 ‘이연’ 베스트 활약상 셋', '이태리, ‘구미호뎐’ 완전체 이무기로 강렬한 등장→新 빌런 예고', '박은빈 화보, 시크와 러블리 오가는 매력', '‘위캔게임’ 딘딘 母子 첫등장 “연예대상 상상해”', '‘불새 2020’ 홍수아-이재우 초고속 결별…폭풍 눈물', 'Mnet 측 “‘킹덤’ 내년 상반기 편성…현재 출연자 섭외 중” [공식]', '‘구미호뎐’ 新 빌런 이무기=이태리…실검 장악한 강렬 임팩트', '‘컴백’ 트레저, 트랙리스트 공개…멤버 아사히 첫 작사·작곡', '‘맛남의 광장’ 백종원, 참돔 회 뜨기 도전…그의 실력은?', '트와이스→TXT ‘엠카’ 할로윈 특집…몬스타엑스 기현 무대도', '[DA:클립] ‘트로트의 민족’ 송중기 닮은꼴 이예준…눈웃음 매력', '쮸리, 맥심 화보…눈 둘 데 없는 파격 오피스룩', '[DAY컷] 구혜선 “학창시절 아이돌 꿈꿔”…센터 가능한 비주얼', '[TV북마크] ‘아이콘택트’ 황제성·딘딘, 7년 묵은 반려견 출생의 비밀 공개…']

# %% [markdown]
# ## 실습 2. 각 기사의 href 수집하기
# 이전 실습에서 진행된 1,2,3 — 으로 구성된 웹 사이트 형태뿐만이 아니라
#
# 단일 페이지에 여러 가지 링크가 있는 경우가 있습니다. 기사를 클릭하면 해당 기사를 볼 수 있는 url로 이동할 수 있습니다. 이런 url로 이동하는 링크들을 수집하고자 합니다.
#
# HTML Tag 중, 연동된 href를 수집하여 리스트형 변수 list_href에 담아 출력하는 실습을 진행합니다.
#
# https://sports.donga.com/ent?p=1&c=02

# %%
import requests
from bs4 import BeautifulSoup

def get_href(soup) :
    # soup에 저장되어 있는 각 기사에 접근할 수 있는 href들을 담고 있는 리스트를 반환해주세요.
    ul = soup.find("ul", class_="list_news")
    result = []

    for span in ul.find_all("span", class_="tit"):
      result.append(span.find("a")["href"])

    return result

def main():
    list_href = []

    url = "https://sports.donga.com/ent?p=1&c=02"
    result = requests.get(url)
    soup = BeautifulSoup(result.text, "html.parser")

    list_href = get_href(soup)
    print(list_href)

if __name__ == "__main__":
    main()
# Out:
# ['https://sports.donga.com/ent/article/all/20201029/103707076/1', 'https://sports.donga.com/ent/article/all/20201029/103706218/1', 'https://sports.donga.com/ent/article/all/20201029/103706166/1', 'https://sports.donga.com/ent/article/all/20201029/103705983/1', 'https://sports.donga.com/ent/article/all/20201029/103705842/1', 'https://sports.donga.com/ent/article/all/20201029/103705686/1', 'https://sports.donga.com/ent/article/all/20201029/103705673/1', 'https://sports.donga.com/ent/article/all/20201029/103705661/1', 'https://sports.donga.com/ent/article/all/20201029/103705650/1', 'https://sports.donga.com/ent/article/all/20201029/103705632/1', 'https://sports.donga.com/ent/article/all/20201029/103705628/1', 'https://sports.donga.com/ent/article/all/20201029/103705615/1', 'https://sports.donga.com/ent/article/all/20201029/103705613/1', 'https://sports.donga.com/ent/article/all/20201029/103705601/1', 'https://sports.donga.com/ent/article/all/20201029/103705592/1', 'https://sports.donga.com/ent/article/all/20201029/103705586/1', 'https://sports.donga.com/ent/article/all/20201029/103705579/1', 'https://sports.donga.com/ent/article/all/20201029/103705283/1', 'https://sports.donga.com/ent/article/all/20201029/103705261/1', 'https://sports.donga.com/ent/article/all/20201029/103705048/1']

# %% [markdown]
# ## 실습 3. 네이트 최신뉴스 href 수집하기
# 웹 페이지 href 링크들을 수집하여 리스트형 변수 list_href에 담아 출력해봅니다.
#
# https://news.nate.com/recent?mid=n0100

# %%
import requests
from bs4 import BeautifulSoup

    
def get_href(soup) :
    # 각 기사에 접근할 수 있는 href를 리스트로 반환하세요.
    result = []

    div_list = soup.find_all("div", class_="mduSubjectList")

    for div in div_list:
      result.append("https:" + div.find("a")["href"])

    return result
    

def main() :
    list_href = []
    
    # href 수집할 사이트 주소 입력
    url = "https://news.nate.com/recent?mid=n0100"
    req = requests.get(url)
    soup = BeautifulSoup(req.text, "html.parser")
    
    list_href = get_href(soup)
    
    print(list_href)


if __name__ == "__main__" :
    main()
# Out:
# ['https://news.nate.com/view/20201029n44201?mid=n0100', 'https://news.nate.com/view/20201029n44200?mid=n0100', 'https://news.nate.com/view/20201029n44199?mid=n0100', 'https://news.nate.com/view/20201029n44198?mid=n0100', 'https://news.nate.com/view/20201029n44197?mid=n0100', 'https://news.nate.com/view/20201029n44196?mid=n0100', 'https://news.nate.com/view/20201029n44195?mid=n0100', 'https://news.nate.com/view/20201029n44194?mid=n0100', 'https://news.nate.com/view/20201029n44192?mid=n0100', 'https://news.nate.com/view/20201029n44189?mid=n0100', 'https://news.nate.com/view/20201029n44188?mid=n0100', 'https://news.nate.com/view/20201029n37235?mid=n0100', 'https://news.nate.com/view/20201029n44186?mid=n0100', 'https://news.nate.com/view/20201029n44185?mid=n0100', 'https://news.nate.com/view/20201029n02647?mid=n0100', 'https://news.nate.com/view/20201029n43969?mid=n0100', 'https://news.nate.com/view/20201029n43908?mid=n0100', 'https://news.nate.com/view/20201029n36549?mid=n0100', 'https://news.nate.com/view/20201029n44177?mid=n0100', 'https://news.nate.com/view/20201029n44176?mid=n0100']

# %% [markdown]
# ## 실습 4. sbs 뉴스 최신 기사 목록의 내용 수집하기
# 수집하는 페이지에 연동되어 있는 href를 추출하여 href 주소에 있는 내용을 크롤링하고자 합니다.
#
# 앞의 실습은 언론 기사의 href만 크롤링했다면, 이번에는 각 기사의 내용까지 수집하는 법을 실습해봅니다.
#
# 사용 url : https://news.sbs.co.kr/news/newsflash.do?plink=GNB&cooper=SBSNEWS

# %%
import requests
from bs4 import BeautifulSoup

def crawling(soup) :
    # soup 객체에서 추출해야 하는 정보를 찾고 반환하세요.
    # 각각의 href 페이지에 들어있는 기사 내용을 반환합니다.
    div = soup.find("div", class_="text_area")
    result = div.get_text()
    return result
    

def get_href(soup) :
    # soup 객체에서 추출해야 하는 정보를 찾고 반환하세요.
    # 상위 페이지에서의 href를 찾아 리스트로 반환합니다.
    div = soup.find("div", class_="w_news_list type_issue")

    result = []

    for a in div.find_all("a", class_="news"):
      # print("https://news.sbs.co.kr" + a["href"])
      result.append("https://news.sbs.co.kr" + a["href"])
      

    return result
    

def main():
    list_href = []
    list_content = []

    url = "https://news.sbs.co.kr/news/newsflash.do?plink=GNB&cooper=SBSNEWS"
    req = requests.get(url)
    soup = BeautifulSoup(req.text, "html.parser")
    
    list_href = get_href(soup)
    print(list_href)
    
    
    for url in list_href :
        href_req = requests.get(url)
        href_soup = BeautifulSoup(href_req.text, "html.parser")
        result = crawling(href_soup)
        list_content.append(result)
        
    print(list_content)


if __name__ == "__main__":
    main()
# Out:
# https://news.sbs.co.kr/news/endPage.do?news_id=N1006049578
# https://news.sbs.co.kr/news/endPage.do?news_id=N1006049577
# https://news.sbs.co.kr/news/endPage.do?news_id=N1006049576
# https://news.sbs.co.kr/news/endPage.do?news_id=N1006049573
# https://news.sbs.co.kr/news/endPage.do?news_id=N1006049572
# https://news.sbs.co.kr/news/endPage.do?news_id=N1006049569
# https://news.sbs.co.kr/news/endPage.do?news_id=N1006049501
# https://news.sbs.co.kr/news/endPage.do?news_id=N1006049567
# https://news.sbs.co.kr/news/endPage.do?news_id=N1006049423
# https://news.sbs.co.kr/news/endPage.do?news_id=N1006049422
# ['https://news.sbs.co.kr/news/endPage.do?news_id=N1006049578', 'https://news.sbs.co.kr/news/endPage.do?news_id=N1006049577', 'https://news.sbs.co.kr/news/endPage.do?news_id=N1006049576', 'https://news.sbs.co.kr/news/endPage.do?news_id=N1006049573', 'https://news.sbs.co.kr/news/endPage.do?news_id=N1006049572', 'https://news.sbs.co.kr/news/endPage.do?news_id=N1006049569', 'https://news.sbs.co.kr/news/endPage.do?news_id=N1006049501', 'https://news.sbs.co.kr/news/endPage.do?news_id=N1006049567', 'https://news.sbs.co.kr/news/endPage.do?news_id=N1006049423', 'https://news.sbs.co.kr/news/endPage.do?news_id=N1006049422']
# ['\n  일본 교도통신은 지난 2011년 3월 동일본대지진 이후 후쿠시마 제1원전의 복구와 폐로 작업에 참여했던 종사자 가운데 산업재해 인정 건수가 269건으로 집계됐다고 보도했습니다.\n  \n 교도통신이 확보한 후생노동성 자료에 따르면 방사성 오염수 저장탱크를 본격적으로 건설했던 2014년도가 추락 사고 등으로 58건이 인정돼 가장 많았고, 이후 연간 20건 전후로 나타났습니다.\n  \n 암이나 백혈병이 발병한 뒤 방사선 피폭에서 기인한 것으로 인정된 사례는 6건이었습니다.\n  \n 교도통신은 피폭에서 발병까지 시간이 걸리는 경우가 많아 피폭에 의한 산재 인정 건수는 앞으로 더 늘어날 가능성이 있다고 전했습니다.\n  \n 과로로 인한 뇌·심장 질환은 4건이었고, 심리적 압박에 따른 정신질환 관련 산재도 4건으로 확인됐습니다.\n  \n 이 밖에 통기성이 나쁜 전면 마스크와 보호복 착용으로 열사병에 걸려 산재를 인정받은 사례가 적지 않았습니다.\n  \n 도쿄전력에 따르면 앞으로 30~40년간 후쿠시마 제1원전의 폐로 작업이 진행될 예정으로, 현재도 하루
  \n 인삼공사가 32대31, 단 한 점 앞선 박빙의 전반이 지나고 3쿼터 외국인 선수 타일러 데이비스(KCC), 얼 클락(인삼공사)의 '장군 멍군'이 이어진 가운데 KCC가 주도권을 잡았습니다.\n  \n 클락이 3점 슛을 포함해 5연속 득점을 뽑아내며 인삼공사가 39대35로 앞섰으나 KCC는 데이비스가 덩크슛 2방 등 6점을 몰아치고 이정현이 2점을 더해 43대39로 전세를 뒤집었습니다.\n  \n 이어지던 접전에서 KCC는 정창영과 데이비스의 연속 레이업 득점으로 3쿼터 40초를 남기고 56대50으로 격차를 벌렸습니다.\n  \n 인삼공사는 이재도가 3쿼터 종료 버저와 함께 하프라인에서 쏜 3점포가 그대로 빨려 들어가며 3점 차로 따라가 흐름을 바꿀 기회를 맞 ...

# %% [markdown]
# ## 실습 5. 다양한 섹션의 속보 기사 href 추출하기
# 네이버 뉴스 속보 페이지에는 여러 섹션이 있습니다.
#
# “정치”, “경제”, “사회”, “생활”, “세계”, “과학” 으로 나뉘어진 다양한 분야의 속보 기사를 추출하고자 합니다.
#
# https://news.naver.com/main/list.nhn?sid1=100
#
# 위 url에서, sid1 부분으로 분야를 설정할 수 있습니다.
#
# sid1	분야	sid1	분야
# 100	정치	103	생활
# 101	경제	104	세계
# 102	사회	105	과학

# %%
import requests
from bs4 import BeautifulSoup

def get_href(soup) :
    # 각 분야별 속보 기사에 접근할 수 있는 href를 리스트로 반환하세요.
    ul = soup.find("ul", class_="type06_headline")
    result = []

    for a in ul.find_all("a", class_="nclicks(fls.list)"):
      result.append(a["href"])

    return result

def get_request(section) :
    # 입력된 분야에 맞는 request 객체를 반환하세요.
    # 아래 url에 쿼리를 적용한 것을 반환합니다.
    custom_header = {
        'referer' : 'https://www.naver.com/',
        'user-agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36'
    }
    
    url = "https://news.naver.com/main/list.nhn"
    
    sections = {
        "정치": 100, 
        "경제": 101, 
        "사회": 102, 
        "생활": 103, 
        "세계": 104, 
        "과학": 105
    }

    req = requests.get(url, headers = custom_header, params = {"sid1": sections[section]}) # params 매개변수를 올바르게 설정하세요.
    
    return req

def main() :
    list_href = []
    
    # 섹션을 입력하세요.
    section = input('"정치", "경제", "사회", "생활", "세계", "과학" 중 하나를 입력하세요.\n  > ')
    
    req = get_request(section)
    soup = BeautifulSoup(req.text, "html.parser")
    
    list_href = get_href(soup)
    
    print(list_href)


if __name__ == "__main__" :
    main()
# Out:
# "정치", "경제", "사회", "생활", "세계", "과학" 중 하나를 입력하세요.
#   > 정치
# ['https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=005&aid=0001375888', 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=005&aid=0001375888', 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=422&aid=0000454528', 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=422&aid=0000454528', 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=057&aid=0001513962', 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=018&aid=0004772952', 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=018&aid=0004772952', 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=081&aid=0003135356', 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=081&aid=0003135356', 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=025&aid=0003047978', 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=025&aid=0003047978', 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=052&aid=0001508091', 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=052&aid=0001508091', 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=003&aid=0010157162', 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=003&aid=0010157162', 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=011&aid=0003818272', 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=011&aid=0003818272', 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=018&aid=0004772948', 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=018&aid=0004772948']

# %% [markdown]
# ### 실습 6. 다양한 섹션의 속보 기사 내용 추출하기
# 다양한 섹션의 속보 기사 href 추출하기 실습과 마찬가지로 네이버 뉴스 속보 페이지에서 실습을 진행합니다.
#
# 사용 url :
# https://news.naver.com/main/list.nhn
#
# 이번에는 특정 분야를 입력받으면 해당 분야의 속보 기사들의 href를 얻고, 그 href로 각각의 기사로 접근하여 기사의 내용을 크롤링하려고 합니다.
#
# 출력 예시

# %%
import requests
from bs4 import BeautifulSoup

def crawling(soup) :
    # 기사에서 내용을 추출하고 반환하세요.
    div = soup.find("div", class_="_article_body_contents")

    # result = div.get_text()
    # print(result)

    result = div.get_text().replace('\n', '').replace('// flash 오류를 우회하기 위한 함수 추가function _flash_removeCallback() {}', '').replace('\t', '')
    
    return result

def get_href(soup) :
    # 각 분야별 속보 기사에 접근할 수 있는 href를 리스트로 반환하세요.

    result = []

    for ul in soup.find_all("ul", class_="type06_headline"):
      for a in ul.find_all("a"):
        result.append(a["href"])

    return result

def get_request(section) :
    # 입력된 분야에 맞는 request 객체를 반환하세요.
    # 아래 url에 쿼리를 적용한 것을 반환합니다.
    custom_header = {
        'referer' : 'https://www.naver.com/',
        'user-agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36'
    }

    section_dict = {
        "정치": 100, 
        "경제": 101, 
        "사회": 102, 
        "생활": 103, 
        "세계": 104, 
        "과학": 105
    }
    
    url = "https://news.naver.com/main/list.nhn"
    
    req = requests.get(url, headers = custom_header,
            params = {"sid1": section_dict[section]}) # params 매개변수를 올바르게 설정하세요.
    return req
    

def main() :
    custom_header = {
        'referer' : 'https://www.naver.com/',
        'user-agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36'
    }
    
    list_href = []
    result = []
    
    # 섹션을 입력하세요.
    section = input('"정치", "경제", "사회", "생활", "세계", "과학" 중 하나를 입력하세요.\n  > ')
    
    req = get_request(section)
    soup = BeautifulSoup(req.text, "html.parser")
    
    list_href = get_href(soup)
    
    for href in list_href :
        href_req = requests.get(href, headers = custom_header)
        href_soup = BeautifulSoup(href_req.text, "html.parser")
        result.append(crawling(href_soup))
    print(result)


if __name__ == "__main__" :
    main()
# Out:
# "정치", "경제", "사회", "생활", "세계", "과학" 중 하나를 입력하세요.
#   > 경제
# ['13일(현지시간) 프랑스 북부 고쥐코르에서 한 남성이 백신을 맞고 있다. © 로이터=뉴스1(서울=뉴스1) 한상희 기자 = 영국 정부가 신종 코로나바이러스 감염증(코로나19) 백신의 신속한 허가를 위해 화이자와 아스트라제네카 백신 임상시험 자료에 대한 사전검토(rolling reviews)를 시작했다.블룸버그통신은 복수의 소식통을 인용, 영국 의약품·건강관리제품 규제당국(MHRA)이 몇 주 전 두 회사에서 개발 중인 코로나19 백신에 대한 사전검토에 들어갔다고 29일(현지시간) 보도했다. 사전검토란 공중보건비상사태가 발생했을 때, 백신과 의약품을 빠르게 평가하기 위해 사용하는 제도다. 평소라면 각 백신개발업체가 임상3상까지 모두 마친 뒤 규제당국에 공식 신청서를 제출해야 한다. 하지만 사전검토의 경우 정부가 현재 진행 중인 연구를 실시간으로 볼 수 있고, 충분한 자료가 확보됐다고 판단되면 제약사 측에 공식 신청서를 제출하도록 한다. 영국과 유럽연합(EU)에서 시행하고 있다. 이 추세라면 영국에서 코로나19
. 무단 전재 및 재배포 금지', '동영상 뉴스[앵커]코로나19 상황이 길어지면서 소상공인들의 시름이 깊죠. 정부가 오늘(30일)부터 외식이나 여행을 하면 할인해주는 행사를 지원합니다. 방역과 내수 살리기, 둘 다 놓칠 수 없다는 건데요.어떻게 할인받을 수 있는지, 이희령 기자와 함께 알아보겠습니다.[기자]오늘부터 주말에 외식을 3번 하면 네 번째 외식비에서 만 원을 돌려주는데요.매주 금요일 오후 4시부터 일요일 자정 사이, 카드로 결제할 때만 됩니다.금액 제한도 있습니다.한 번 외식할 때 2만 원 이상 써야 합니다.8만 원 이상 써야 만 원을 깎아주는 셈입니다.카드사별로 하루에 두 번까지, 같은 업소는 한 번만 외식 횟수가 인정됩니다.안 되는 곳들도 있습니다.유흥주점, 구내식당, 백화점이나 쇼핑몰 ...

# %% [markdown]
# ## 실습 7 특정 영화 리뷰 추출하기
# 리뷰를 알고 싶은 영화의 제목을 입력하면, 해당 영화의 리뷰들의 제목을 알려주는 프로그램을 제작해봅시다.

# %%
import requests
from bs4 import BeautifulSoup

def crawling(soup) :
    # soup 객체에서 추출해야 하는 정보를 찾고 반환하세요.
    # 1장 실습의 영화 리뷰 추출 방식과 동일합니다.
    result = []
    ul = soup.find("ul", class_="rvw_list_area")

    for li in ul.find_all("li"):
      result.append(li.find("strong").get_text())
    return result
    
def get_href(soup) :
    # 검색 결과, 가장 위에 있는 영화로 접근할 수 있는 href를 반환하세요.
    ul = soup.find("ul", class_="search_list_1")

    a = ul.find("a")

    href = a['href'].replace('basic', 'review')
    return "https://movie.naver.com" + href
    

def get_url(movie) :
    # 입력된 영화를 검색한 결과의 url을 반환하세요.
    return f"https://movie.naver.com/movie/search/result.nhn?query={movie}&section=all&ie=utf8"

    
def main() :
    list_href = []
    
    custom_header = {
        'referer' : 'https://www.naver.com/',
        'user-agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36'
    }
    
    # 섹션을 입력하세요.
    movie = input('영화 제목을 입력하세요. \n  > ')
    
    url = get_url(movie)
    print(url)
    req = requests.get(url, headers = custom_header)
    soup = BeautifulSoup(req.text, "html.parser")
    
    movie_url = get_href(soup)
    print(movie_url)
    
    href_req = requests.get(movie_url)
    href_soup = BeautifulSoup(href_req.text, "html.parser")
    
    list_href = crawling(href_soup)
    print(list_href)
    


if __name__ == "__main__" :
    main()
# Out:
# 영화 제목을 입력하세요.
#   > 기생충
# https://movie.naver.com/movie/search/result.nhn?query=기생충&section=all&ie=utf8
# https://movie.naver.com/movie/bi/mi/review.nhn?code=161967
# ['ㅋㅋ 이미 영화가 다보이네', '(스포, 해석)인간은 높은 곳 낮은 곳 어디에나 존재하고, 존재하지 않는다.', '봉준호가 계층 계급에 집착하는 이유', '자본주의비판노노..인식에대하여 +한국판 웨스앤더슨의 대칭의 미학', '<결말해석> 누가 진짜 기생충이게? 원주민 행세를 하는 가짜 인디언을 찾아야 한다.', "기생충, 사회 시스템과 '공생' 에 관한 사회 스릴러!", '지렷다....', '기생충 후기, 결말은 빈부격차 현실을 잘 표현한 영화다..', '진짜 모르겠다.', '대충 어떤식의 영화일지 감이 옴']
